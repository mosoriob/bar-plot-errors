# %%
import numpy as np
import pandas
import matplotlib.pyplot as plt

# %%
input_file='HMEC1_tiaca1_09_09_22_Corregido.csv'

# %%
data = pandas.read_csv(input_file, header=0, index_col=None)

# %%
data
# Out:
#     extracto descripción  solvente  concentracion_microg_ml  abs_540_ SRB  \
# 0      tiaca  c_negativo         0                        0         0.516
# 1      tiaca  c_negativo         0                        0         0.516
# 2      tiaca  c_negativo         0                        0         0.502
# 3      tiaca  c_negativo         0                        0         0.454
# 4      tiaca  c_negativo         0                        0         0.489
# ..       ...         ...       ...                      ...           ...
# 187    tiaca  c_solvente         5                        0         0.429
# 188    tiaca  c_solvente         5                        0         0.458
# 189    tiaca  c_solvente         5                        0         0.473
# 190    tiaca  c_solvente         5                        0         0.528
# 191    tiaca  c_solvente         5                        0         0.441
#
#      porcentaje_viabiliadad_control_solvente  placa
# ...

# %%
negativo = data.loc[data['solvente'] == 0] 
c_solvente = data.loc[data['solvente'] == 5]

# %%
hexano_50 = data.loc[(data['solvente'] == 1) & (data['concentracion_microg_ml'] == 50)] 
hexano_125 = data.loc[(data['solvente'] == 1) & (data['concentracion_microg_ml'] == 125)] 
hexano_250 = data.loc[(data['solvente'] == 1) & (data['concentracion_microg_ml'] == 250)] 
hexano_375 = data.loc[(data['solvente'] == 1) & (data['concentracion_microg_ml'] == 375)] 
hexano_500 = data.loc[(data['solvente'] == 1) & (data['concentracion_microg_ml'] == 500)]

# %%
diclorometano_50 = data.loc[(data['solvente'] == 2) & (data['concentracion_microg_ml'] == 50)] 
diclorometano_125 = data.loc[(data['solvente'] == 2) & (data['concentracion_microg_ml'] == 125)] 
diclorometano_250 = data.loc[(data['solvente'] == 2) & (data['concentracion_microg_ml'] == 250)] 
diclorometano_375 = data.loc[(data['solvente'] == 2) & (data['concentracion_microg_ml'] == 375)] 
diclorometano_500 = data.loc[(data['solvente'] == 2) & (data['concentracion_microg_ml'] == 500)] 
diclorometano_50_mean = np.std(diclorometano_50)
diclorometano_125_mean = np.std(diclorometano_125)
diclorometano_250_mean = np.std(diclorometano_250)
diclorometano_375_mean = np.std(diclorometano_375)
diclorometano_500_mean = np.std(diclorometano_500)
diclorometano_50_error = np.std(diclorometano_50)

# %%
acetato_de_etilo_50 = data.loc[(data['solvente'] == 3) & (data['concentracion_microg_ml'] == 50)] 
acetato_de_etilo_125 = data.loc[(data['solvente'] == 3) & (data['concentracion_microg_ml'] == 125)] 
acetato_de_etilo_250 = data.loc[(data['solvente'] == 3) & (data['concentracion_microg_ml'] == 250)] 
acetato_de_etilo_375 = data.loc[(data['solvente'] == 3) & (data['concentracion_microg_ml'] == 375)] 
acetato_de_etilo_500 = data.loc[(data['solvente'] == 3) & (data['concentracion_microg_ml'] == 500)]

# %%
etanol_50 = data.loc[(data['solvente'] == 4) & (data['concentracion_microg_ml'] == 50)] 
etanol_125 = data.loc[(data['solvente'] == 4) & (data['concentracion_microg_ml'] == 125)] 
etanol_250 = data.loc[(data['solvente'] == 4) & (data['concentracion_microg_ml'] == 250)] 
etanol_375 = data.loc[(data['solvente'] == 4) & (data['concentracion_microg_ml'] == 375)] 
etanol_500 = data.loc[(data['solvente'] == 4) & (data['concentracion_microg_ml'] == 500)]

# %%
etanol_375
# Out:
#     extracto descripción  solvente  concentracion_microg_ml  abs_540_ SRB  \
# 72     tiaca      etanol         4                      375         0.487
# 73     tiaca      etanol         4                      375         0.670
# 74     tiaca      etanol         4                      375         0.543
# 75     tiaca      etanol         4                      375         0.512
# 168    tiaca      etanol         4                      375         0.531
# 169    tiaca      etanol         4                      375         0.553
# 170    tiaca      etanol         4                      375         0.482
# 171    tiaca      etanol         4                      375         0.666
#
#      porcentaje_viabiliadad_control_solvente  placa
# 72                                   106.332      1
# 73                                   146.288      1
# 74                                   118.559      1
# 75                                   111.790      1
# ...
